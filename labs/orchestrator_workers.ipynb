# %% [markdown]
# ## Orchestrator-Workers Workflow
# In this workflow, a central LLM dynamically breaks down tasks, delegates them to worker LLMs, and synthesizes their results.
#
# ### When to use this workflow
# This workflow is well-suited for complex tasks where you can't predict the subtasks needed. The key difference from simple parallelization is its flexibility—subtasks aren't pre-defined, but determined by the orchestrator based on the specific input.

# %%
#!pip install anthropic

# %% [markdown]
# ### Get API Key
#
# Buy $5 credits.
# https://console.anthropic.com/dashboard

# %%
# Set environment varaible. Needed by util.py

import os

ANTHROPIC_API_KEY = "xxx"

os.environ["ANTHROPIC_API_KEY"] = ANTHROPIC_API_KEY

# %%
from typing import Dict, List, Optional
from util import llm_call, extract_xml

def parse_tasks(tasks_xml: str) -> List[Dict]:
    """Parse XML tasks into a list of task dictionaries."""
    tasks = []
    current_task = {}
    
    for line in tasks_xml.split('\n'):
        line = line.strip()
        if not line:
            continue
            
        if line.startswith("<task>"):
            current_task = {}
        elif line.startswith("<type>"):
            current_task["type"] = line[6:-7].strip()
        elif line.startswith("<description>"):
            current_task["description"] = line[12:-13].strip()
        elif line.startswith("</task>"):
            if "description" in current_task:
                if "type" not in current_task:
                    current_task["type"] = "default"
                tasks.append(current_task)
    
    return tasks

class FlexibleOrchestrator:
    """Break down tasks and run them in parallel using worker LLMs."""
    
    def __init__(
        self,
        orchestrator_prompt: str,
        worker_prompt: str,
    ):
        """Initialize with prompt templates."""
        self.orchestrator_prompt = orchestrator_prompt
        self.worker_prompt = worker_prompt

    def _format_prompt(self, template: str, **kwargs) -> str:
        """Format a prompt template with variables."""
        try:
            return template.format(**kwargs)
        except KeyError as e:
            raise ValueError(f"Missing required prompt variable: {e}")

    def process(self, task: str, context: Optional[Dict] = None) -> Dict:
        """Process task by breaking it down and running subtasks in parallel."""
        context = context or {}
        
        # Step 1: Get orchestrator response
        orchestrator_input = self._format_prompt(
            self.orchestrator_prompt,
            task=task,
            **context
        )
        orchestrator_response = llm_call(orchestrator_input)
        
        # Parse orchestrator response
        analysis = extract_xml(orchestrator_response, "analysis")
        tasks_xml = extract_xml(orchestrator_response, "tasks")
        tasks = parse_tasks(tasks_xml)
        
        print("\n=== ORCHESTRATOR OUTPUT ===")
        print(f"\nANALYSIS:\n{analysis}")
        print(f"\nTASKS:\n{tasks}")
        
        # Step 2: Process each task
        worker_results = []
        for task_info in tasks:
            worker_input = self._format_prompt(
                self.worker_prompt,
                original_task=task,
                task_type=task_info['type'],
                task_description=task_info['description'],
                **context
            )
            
            worker_response = llm_call(worker_input)
            result = extract_xml(worker_response, "response")
            
            worker_results.append({
                "type": task_info["type"],
                "description": task_info["description"],
                "result": result
            })
            
            print(f"\n=== WORKER RESULT ({task_info['type']}) ===\n{result}\n")
        
        return {
            "analysis": analysis,
            "worker_results": worker_results,
        }

# %% [markdown]
# ### Example Use Case: Marketing Variation Generation

# %%
ORCHESTRATOR_PROMPT = """
Analyze this task and break it down into 2-3 distinct approaches:

Task: {task}

Return your response in this format:

<analysis>
Explain your understanding of the task and which variations would be valuable.
Focus on how each approach serves different aspects of the task.
</analysis>

<tasks>
    <task>
    <type>formal</type>
    <description>Write a precise, technical version that emphasizes specifications</description>
    </task>
    <task>
    <type>conversational</type>
    <description>Write an engaging, friendly version that connects with readers</description>
    </task>
</tasks>
"""

WORKER_PROMPT = """
Generate content based on:
Task: {original_task}
Style: {task_type}
Guidelines: {task_description}

Return your response in this format:

<response>
Your content here, maintaining the specified style and fully addressing requirements.
</response>
"""


orchestrator = FlexibleOrchestrator(
    orchestrator_prompt=ORCHESTRATOR_PROMPT,
    worker_prompt=WORKER_PROMPT,
)

results = orchestrator.process(
    task="Write a product description for a new eco-friendly water bottle",
    context={
        "target_audience": "environmentally conscious millennials",
        "key_features": ["plastic-free", "insulated", "lifetime warranty"]
    }
)
# Out:
# === ORCHESTRATOR OUTPUT ===
#
# ANALYSIS:
#
# This task requires creating marketing copy for an eco-friendly water bottle, which presents an opportunity to approach it from multiple angles given the dual nature of the product - its functional purpose (holding water) and its environmental benefits. The key variations should address different buyer motivations:
#
# 1. Technical buyers who want specific details about materials, construction, and environmental impact
# 2. Lifestyle-focused consumers who care about both sustainability and how the product fits into their daily lives
# 3. Value-driven customers who want to understand both practical benefits and environmental impact
#
# The most effective approaches would be to focus on either technical precision or emotional connection, as these serve the two main purchasing drivers for eco-friendly products.
#
#
# TASKS:
# [{'type': 'formal', 'description': '>Create a specification-focused description highlighting material composition, manufacturing process, environmental certifications, and quantifiable benefits (e.g., "Made from 100% recycled stainless steel, BPA-free construction, reduces plastic waste by X units per year")<'}, {'type': 'conversational', 'description': '>Develop a narrative-style description that emphasizes lifestyle benefits and environmental impact through relatable scenarios and emotional appeals (e.g., "Imagine carrying your favorite drinks in a bottle that\'s as kind to the planet as it is to you...")<'}]
#
# === WORKER RESULT (formal) ===
#
# Introducing the EcoVessel Elite: A premium sustainable hydration solution engineered for environmental consciousness and superior performance.
#
# Product Specifications:
# - Constructed from 100% post-consumer recycled stainless steel
# - 750ml capacity with precision-calibrated measurement markings
# - Double-wall vacuum insulation maintains temperature (24 hours cold, 12 hours hot)
# - Zero BPA, phthalates, or harmful chemicals
# - ISO 14001 certified manufacturing process
#
# Environmental Impact:
# - Eliminates approximately 1,100 single-use plastic bottles per year of regular use
# - Carbon-neutral manufacturing facility powered by renewable energy
# - 95% reduced carbon footprint compared to conventional steel production
# - Cradle-to-cradle certified design ensures 100% recyclability
#
# Technical Features:
# - Proprietary Bio-Shield™ antimicrobial interior coating
# - Leak-proof architecture with aerospace-grade threading
# - Impact-resistant exterior with lifetime structural warranty
# - Advanced filtration compatibility (0.2-micron filter capacity)
#
# Sustainability Certifications:
# - B Corp Certified manufacturer
# - Green Seal Environmental Innovation certification
# - EPA SmartWay Transport Partner
# - Forest Stewardship Council certified packaging
#
# Each EcoVessel Elite represents the elimination of approximately 22.6 kg of plastic waste annually while delivering professional-grade hydration performance through environmentally responsible engineering.
#
#
#
# === WORKER RESULT (conversational) ===
#
# Hey there, fellow Earth-lover! Let me tell you about your new favorite companion in the battle against plastic waste - the EcoFlow Hydration Bottle.
#
# Imagine starting your day knowing you're already making a difference. That's exactly what happens when you grab your EcoFlow, a sleek water bottle that's as kind to the planet as it is to you. Picture this: you're hitting the gym, hiking your favorite trail, or crushing it at the office, all while keeping your drinks perfectly chilled for 24 hours (or toasty warm for 12, if that's your thing!).
#
# You know that guilty feeling when you have to grab a disposable bottle at the airport? Kiss it goodbye! Your EcoFlow is made from premium recycled stainless steel that's built to last literally thousands of refills. That's like saving an entire army of single-use bottles from ending up in our oceans. Pretty cool, right?
#
# But here's what'll really make you smile - every EcoFlow bottle helps fund ocean cleanup projects. So while you're sipping your morning coffee or staying hydrated during yoga class, you're actually part of something bigger. Plus, the wide-mouth design means you can easily toss in some ice cubes or give it a proper clean (because nobody likes that funky bottle smell, am I right?).
#
# And let's talk style - because doing good should look good too! The EcoFlow comes in nature-inspired colors that'll have your colleagues asking "Where did you get that?" faster than you can say "saving the planet."
#
# Ready to make every sip count? Your future self (and our planet) will thank you for making the switch to EcoFlow. Because sometimes the smallest changes make the biggest waves! 🌊🌿
